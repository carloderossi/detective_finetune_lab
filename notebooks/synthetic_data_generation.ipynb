# %%
# !nvidia-smi
# Out:
# Fri Feb 20 07:33:42 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   66C    P8             13W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# --- CLEAN START ---
# Remove everything that can conflict
# !pip uninstall -y unsloth unsloth-zoo transformers accelerate peft datasets tokenizers huggingface-hub bitsandbytes sentencepiece

# --- PYTORCH (CUDA 11.8) ---
# !pip install torch --index-url https://download.pytorch.org/whl/cu118

# --- INSTALL MODERN UNSLOTH (the correct one for Qwen2.5) ---
# !pip install "unsloth==2026.2.1"

# --- INSTALL THE HF STACK COMPATIBLE WITH UNSLOTH 2026.x ---
# !pip install "transformers>=4.57.0" "accelerate>=0.34.1" "peft>=0.18.0" datasets sentencepiece bitsandbytes

# --- OPTIONAL EXTRAS ---
# !pip install wandb plotly
# Out:
# WARNING: Skipping unsloth as it is not installed.
# WARNING: Skipping unsloth-zoo as it is not installed.
# Found existing installation: transformers 5.0.0
# Uninstalling transformers-5.0.0:
#   Successfully uninstalled transformers-5.0.0
# Found existing installation: accelerate 1.12.0
# Uninstalling accelerate-1.12.0:
#   Successfully uninstalled accelerate-1.12.0
# Found existing installation: peft 0.18.1
# Uninstalling peft-0.18.1:
#   Successfully uninstalled peft-0.18.1
# Found existing installation: datasets 4.0.0
# Uninstalling datasets-4.0.0:
#   Successfully uninstalled datasets-4.0.0
# Found existing installation: tokenizers 0.22.2
# Uninstalling tokenizers-0.22.2:
#   Successfully uninstalled tokenizers-0.22.2
# Found existing installation: huggingface_hub 1.4.1
# Uninstalling huggingface_hub-1.4.1:
#   Successfully uninstalled huggingface_hub-1.4.1
# WARNING: Skipping bitsandbytes as it is not installed.
# Found existing installation: sentencepiece 0.2.1
# Uninstalling sentencepiece-0.2.1:
#   Successfully uninstalled sentencepiece-0.2.1
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.10.0+cu128)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.24.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch) (1.3.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Collecting unsloth==2026.2.1
#   Downloading unsloth-2026.2.1-py3-none-any.whl.metadata (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.7/69.7 kB 4.9 MB/s eta 0:00:00
# Collecting unsloth_zoo>=2026.2.1 (from unsloth==2026.2.1)
#   Downloading unsloth_zoo-2026.2.1-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: wheel>=0.42.0 in /usr/local/lib/python3.12/dist-packages (from unsloth==2026.2.1) (0.46.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from unsloth==2026.2.1) (26.0)
# Requirement already satisfied: torch>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from unsloth==2026.2.1) (2.10.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from unsloth==2026.2.1) (0.25.0+cu128)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from unsloth==2026.2.1) (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from unsloth==2026.2.1) (4.67.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from unsloth==2026.2.1) (5.9.5)
# Collecting tyro (from unsloth==2026.2.1)
#   Downloading tyro-1.0.6-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from unsloth==2026.2.1) (5.29.6)
# Collecting xformers>=0.0.27.post2 (from unsloth==2026.2.1)
#   Downloading xformers-0.0.34-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (1.2 kB)
# Collecting bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5 (from unsloth==2026.2.1)
#   Downloading bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: triton>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from unsloth==2026.2.1) (3.6.0)
# Collecting sentencepiece>=0.2.0 (from unsloth==2026.2.1)
#   Downloading sentencepiece-0.2.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Collecting datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1 (from unsloth==2026.2.1)
#   Downloading datasets-4.3.0-py3-none-any.whl.metadata (18 kB)
# Collecting accelerate>=0.34.1 (from unsloth==2026.2.1)
#   Downloading accelerate-1.12.0-py3-none-any.whl.metadata (19 kB)
# Collecting peft!=0.11.0,>=0.18.0 (from unsloth==2026.2.1)
#   Downloading peft-0.18.1-py3-none-any.whl.metadata (14 kB)
# Collecting huggingface_hub>=0.34.0 (from unsloth==2026.2.1)
#   Downloading huggingface_hub-1.4.1-py3-none-any.whl.metadata (13 kB)
# Collecting hf_transfer (from unsloth==2026.2.1)
#   Downloading hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: diffusers in /usr/local/lib/python3.12/dist-packages (from unsloth==2026.2.1) (0.36.0)
# Collecting transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,!=4.57.4,!=4.57.5,<=4.57.6,>=4.51.3 (from unsloth==2026.2.1)
#   Downloading transformers-4.57.6-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.8 MB/s eta 0:00:00
# Collecting trl!=0.19.0,<=0.24.0,>=0.18.2 (from unsloth==2026.2.1)
#   Downloading trl-0.24.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.34.1->unsloth==2026.2.1) (6.0.3)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.34.1->unsloth==2026.2.1) (0.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.2.1) (3.24.2)
# Collecting pyarrow>=21.0.0 (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.2.1)
#   Downloading pyarrow-23.0.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.1 kB)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.2.1) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.2.1) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.2.1) (2.32.4)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.2.1) (0.28.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.2.1) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.2.1) (0.70.16)
# Requirement already satisfied: fsspec<=2025.9.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.2.1) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.34.0->unsloth==2026.2.1) (1.2.0)
# Requirement already satisfied: shellingham in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.34.0->unsloth==2026.2.1) (1.5.4)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.34.0->unsloth==2026.2.1) (0.24.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.34.0->unsloth==2026.2.1) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2026.2.1) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2026.2.1) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2026.2.1) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2026.2.1) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2026.2.1) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2026.2.1) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2026.2.1) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2026.2.1) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2026.2.1) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2026.2.1) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2026.2.1) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2026.2.1) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2026.2.1) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2026.2.1) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2026.2.1) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2026.2.1) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2026.2.1) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2026.2.1) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2026.2.1) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2026.2.1) (1.13.1.3)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.4.0->unsloth==2026.2.1) (1.3.4)
# Collecting huggingface_hub>=0.34.0 (from unsloth==2026.2.1)
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,!=4.57.4,!=4.57.5,<=4.57.6,>=4.51.3->unsloth==2026.2.1) (2025.11.3)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,!=4.57.4,!=4.57.5,<=4.57.6,>=4.51.3->unsloth==2026.2.1)
#   Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Collecting torchao>=0.13.0 (from unsloth_zoo>=2026.2.1->unsloth==2026.2.1)
#   Downloading torchao-0.16.0-cp310-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (20 kB)
# Collecting cut_cross_entropy (from unsloth_zoo>=2026.2.1->unsloth==2026.2.1)
#   Downloading cut_cross_entropy-25.1.1-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo>=2026.2.1->unsloth==2026.2.1) (11.3.0)
# Collecting msgspec (from unsloth_zoo>=2026.2.1->unsloth==2026.2.1)
#   Downloading msgspec-0.20.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.12/dist-packages (from diffusers->unsloth==2026.2.1) (8.7.1)
# Requirement already satisfied: docstring-parser>=0.15 in /usr/local/lib/python3.12/dist-packages (from tyro->unsloth==2026.2.1) (0.17.0)
# Requirement already satisfied: typeguard>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from tyro->unsloth==2026.2.1) (4.5.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.2.1) (3.13.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.2.1) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.2.1) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.2.1) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.2.1) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.2.1) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.2.1) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.2.1) (2.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.4.0->unsloth==2026.2.1) (1.3.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata->diffusers->unsloth==2026.2.1) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.4.0->unsloth==2026.2.1) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.2.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.2.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.2.1) (2025.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.2.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.2.1) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.2.1) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.2.1) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.2.1) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.2.1) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.2.1) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.2.1) (1.17.0)
# Requirement already satisfied: typer>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim->huggingface_hub>=0.34.0->unsloth==2026.2.1) (0.24.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim->huggingface_hub>=0.34.0->unsloth==2026.2.1) (8.3.1)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim->huggingface_hub>=0.34.0->unsloth==2026.2.1) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim->huggingface_hub>=0.34.0->unsloth==2026.2.1) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface_hub>=0.34.0->unsloth==2026.2.1) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface_hub>=0.34.0->unsloth==2026.2.1) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface_hub>=0.34.0->unsloth==2026.2.1) (0.1.2)
# Downloading unsloth-2026.2.1-py3-none-any.whl (432 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 432.3/432.3 kB 23.3 MB/s eta 0:00:00
# Downloading accelerate-1.12.0-py3-none-any.whl (380 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.9/380.9 kB 44.0 MB/s eta 0:00:00
# Downloading bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl (60.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 13.6 MB/s eta 0:00:00:00:0100:01
# Downloading datasets-4.3.0-py3-none-any.whl (506 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.8/506.8 kB 52.2 MB/s eta 0:00:00
# Downloading peft-0.18.1-py3-none-any.whl (556 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.0/557.0 kB 58.0 MB/s eta 0:00:00
# Downloading sentencepiece-0.2.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 95.9 MB/s eta 0:00:00
# Downloading transformers-4.57.6-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 122.1 MB/s eta 0:00:0000:010:01
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 34.0 MB/s eta 0:00:00
# Downloading trl-0.24.0-py3-none-any.whl (423 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 kB 49.0 MB/s eta 0:00:00
# Downloading unsloth_zoo-2026.2.1-py3-none-any.whl (376 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 376.5/376.5 kB 44.3 MB/s eta 0:00:00
# Downloading xformers-0.0.34-cp39-abi3-manylinux_2_28_x86_64.whl (110.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.8/110.8 MB 8.0 MB/s eta 0:00:00:00:0100:01
# Downloading hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 131.9 MB/s eta 0:00:00
# Downloading tyro-1.0.6-py3-none-any.whl (181 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 22.2 MB/s eta 0:00:00
# Downloading pyarrow-23.0.1-cp312-cp312-manylinux_2_28_x86_64.whl (47.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 19.6 MB/s eta 0:00:00:00:0100:01
# Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 117.2 MB/s eta 0:00:00
# Downloading torchao-0.16.0-cp310-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 128.4 MB/s eta 0:00:00
# Downloading cut_cross_entropy-25.1.1-py3-none-any.whl (22 kB)
# Downloading msgspec-0.20.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.9/224.9 kB 28.1 MB/s eta 0:00:00
# Installing collected packages: torchao, sentencepiece, pyarrow, msgspec, hf_transfer, tyro, huggingface_hub, tokenizers, xformers, transformers, datasets, cut_cross_entropy, bitsandbytes, accelerate, trl, peft, unsloth_zoo, unsloth
#   Attempting uninstall: torchao
#     Found existing installation: torchao 0.10.0
#     Uninstalling torchao-0.10.0:
#       Successfully uninstalled torchao-0.10.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
# Successfully installed accelerate-1.12.0 bitsandbytes-0.49.2 cut_cross_entropy-25.1.1 datasets-4.3.0 hf_transfer-0.1.9 huggingface_hub-0.36.2 msgspec-0.20.0 peft-0.18.1 pyarrow-23.0.1 sentencepiece-0.2.1 tokenizers-0.22.2 torchao-0.16.0 transformers-4.57.6 trl-0.24.0 tyro-1.0.6 unsloth-2026.2.1 unsloth_zoo-2026.2.1 xformers-0.0.34
# Requirement already satisfied: transformers>=4.57.0 in /usr/local/lib/python3.12/dist-packages (4.57.6)
# Requirement already satisfied: accelerate>=0.34.1 in /usr/local/lib/python3.12/dist-packages (1.12.0)
# Requirement already satisfied: peft>=0.18.0 in /usr/local/lib/python3.12/dist-packages (0.18.1)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.3.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (0.2.1)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.12/dist-packages (0.49.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers>=4.57.0) (3.24.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.57.0) (0.36.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.57.0) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.57.0) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.57.0) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.57.0) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers>=4.57.0) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.57.0) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.57.0) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.57.0) (4.67.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.34.1) (5.9.5)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.34.1) (2.10.0+cu128)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (23.0.1)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.28.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.9.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (3.13.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=4.57.0) (1.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=4.57.0) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers>=4.57.0) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers>=4.57.0) (2.5.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=0.34.1) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=0.34.1) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=0.34.1) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=0.34.1) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=0.34.1) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=0.34.1) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=0.34.1) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=0.34.1) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=0.34.1) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=0.34.1) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=0.34.1) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=0.34.1) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=0.34.1) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=0.34.1) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=0.34.1) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=0.34.1) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=0.34.1) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=0.34.1) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=0.34.1) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=0.34.1) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate>=0.34.1) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.0.0->accelerate>=0.34.1) (1.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate>=0.34.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->accelerate>=0.34.1) (3.0.3)
# Requirement already satisfied: wandb in /usr/local/lib/python3.12/dist-packages (0.25.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (5.24.1)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.12/dist-packages (from wandb) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (3.1.46)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from wandb) (26.0)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb) (4.9.2)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (5.29.6)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.12.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from wandb) (6.0.3)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.32.4)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.53.0)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /usr/local/lib/python3.12/dist-packages (from wandb) (4.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly) (9.1.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (2026.1.4)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)

# %%
# %cd /content
# !rm -rf detective_finetune_lab

# !git clone https://github.com/carloderossi/detective_finetune_lab.git
# %cd detective_finetune_lab


# !ls -R
# Out:
# /content
# Cloning into 'detective_finetune_lab'...
# remote: Enumerating objects: 493, done.
# remote: Counting objects: 100% (493/493), done.
# remote: Compressing objects: 100% (385/385), done.
# remote: Total 493 (delta 116), reused 441 (delta 64), pack-reused 0 (from 0)
# Receiving objects: 100% (493/493), 8.47 MiB | 16.21 MiB/s, done.
# Resolving deltas: 100% (116/116), done.
# /content/detective_finetune_lab
# .:
# CDR_OLLAMA_Serve.cmd  notebooks       README.md  scripts
# data		      pyproject.toml  reports	 SomeIMPROVEMENTS.md
#
# ./data:
# cleaned  evaluation  raw  rl  train
#
# ./data/cleaned:
# agatha_christie  arthur_conan_doyle
#
# ./data/cleaned/agatha_christie:
# poirot_investigates_by_agatha_christie
# the_big_four_by_agatha_christie
# the_murder_of_roger_ackroyd_by_agatha_christie
# the_mysterious_affair_at_styles_by_agatha_christie
# the_mystery_of_the_blue_train_by_agatha_christie
#
# ./data/cleaned/agatha_christie/poirot_investigates_by_agatha_christie:
# chapter_01.txt	chapter_04.txt	chapter_07.txt	chapter_10.txt
# chapter_02.txt	chapter_05.txt	chapter_08.txt	chapter_11.txt
# chapter_03.txt	chapter_06.txt	chapter_09.tx
by_arthur_conan_doyle:
# chapter_01.txt	chapter_04.txt	chapter_07.txt	chapter_10.txt
# chapter_02.txt	chapter_05.txt	chapter_08.txt	chapter_11.txt
# chapter_03.txt	chapter_06.txt	chapter_09.txt	chapter_12.txt
#
# ./data/cleaned/arthur_conan_doyle/the_valley_of_fear_by_arthur_conan_doyle:
# chapter_01.txt	chapter_04.txt	chapter_07.txt	chapter_10.txt	chapter_13.txt
# chapter_02.txt	chapter_05.txt	chapter_08.txt	chapter_11.txt	chapter_14.txt
# chapter_03.txt	chapter_06.txt	chapter_09.txt	chapter_12.txt
#
# ./data/evaluation:
# eval_prompt.jsonl  heldout_eval.jsonl
#
# ./data/raw:
# holmes	poirot
#
# ./data/raw/holmes:
# 'A Study in Scarlet by Arthur Conan Doyle.txt'
# 'His last bow - Some later reminiscences of Sherlock Holmes by Arthur Conan Doyle.txt'
# 'The Adventures of Sherlock Holmes by Arthur Conan Doyle.txt'
# 'The case-book of Sherlock Holmes by Arthur Conan Doyle.txt'
# 'The Hound of the Baskervilles by Arthur Conan Doyle.txt'
# 'The Memoirs of Sherlock Holmes by Arthur Conan Doyle.txt'
# 'The Return of Sherlock Holmes by Arthur Conan Doyle.txt'
# 'The Sign of the Four by Arthur Conan Doyle.txt'
# 'The Valley of Fear by Arthur Conan Doyle.txt'
#
# ./data/raw/poirot:
# 'Poirot Investigates by Agatha Christie.txt'
# 'The Big Four by Agatha Christie.txt'
# 'The murder of Roger Ackroyd by Agatha Christie.txt'
# 'The Mysterious Affair at Styles by Agatha Christie.txt'
# 'The mystery of the Blue Train by Agatha Christie.txt'
#
# ./data/rl:
# deduction_prompts.jsonl
#
# ./data/train:
# detective_finetune.jsonl
#
# ./notebooks:
# detective_finetune_lab.ipynb  synthetic_data_generation.ipynb
#
# ./reports:
#  chapter_drift_heatmap.png  'DataSet Quality Check.md'	  style_clusters.png
#  dataset_qa_report.md	     detective_lab_dashboard.py
#
# ./scripts:
# chapters_2_jasonl.py	    generate_deductions_prompt.py
# dataset_quality_checker.py  generate_synthetic_detective_data.py
# datset_report.py	    rl_deduction_ppo.py
# eval_judge.py		    train_scout_unsloth.py
# eval_qwen_detective.py

# %%
import yaml
import os
from google.colab import drive
drive.mount('/content/drive')

with open('/content/drive/MyDrive/TMP/HF_TOKEN.txt') as f:
    token = f.read().strip()
    if token:
        os.environ["HF_TOKEN"] = token
# 2. Check if HF_TOKEN is set in the environment
test_token=os.getenv("HF_TOKEN")
if test_token:
    print("HF_TOKEN is set in the environment.")
# Out:
# Mounted at /content/drive
# HF_TOKEN is set in the environment.

# %%
# !python scripts/generate_synthetic_detective_data.py
# Out:
# 2026-02-20 07:35:21.987173: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771572922.007730     948 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771572922.014568     948 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771572922.031721     948 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771572922.031746     948 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771572922.031750     948 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771572922.031753     948 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-02-20 07:35:22.036239: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# Loading model: Qwen/Qwen2.5-72B-Instruct
# config.json: 100% 663/663 [00:00<00:00, 4.57MB/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 79.0kB [00:00, 48.4MB/s]
# Fetching 37 files:   0% 0/37 [00:00<?, ?it/s]
# model-00001-of-00037.safetensors:   0% 0.00/3.76G [00:00<?, ?B/s]
#
# model-00002-of-00037.safetensors:   0% 0.00/4.00G [00:00<?, ?B/s]
#
#
# model-00003-of-00037.safetensors:   0% 0.00/3.81G [00:00<?, ?B/s]
#
#
#
# model-00006-of-00037.safetensors:   0% 0.00/4.00G [00:00<?, ?B/s]
#
#
#
#
# model-00004-of-00037.safetensors:   0% 0.00/4.00G [00:00<?, ?B/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:   0% 0.00/4.00G [00:00<?, ?B/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:   0% 0.00/3.81G [00:00<?, ?B/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:   0% 0.00/4.00G [00:00<?, ?B/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:   0% 365k/4.00G [00:00<2:58:44, 372kB/s]
#
#
#
#
# model-00004-of-00037.safetensors:   0% 74.0k/4.00G [00:01<17:21:42, 63.9kB/s]
# model-00001-of-00037.safetensors:   0% 723k/3.76G [00:01<1:49:21, 573kB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:   0% 35.5k/4.00G [00:05<182:34:22, 6.08kB/s]
#
#
#
#
# model-00004-of-00037.safetensors:   1% 31.8M/4.00G [00:06<11:47, 5.60MB/s]
# model-00001-of-00037.safetensors:   0% 9.01M/3.76G [00:06<42:31, 1.47MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:   0% 8.32M/3.81G [00:06<52:02, 1.22MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:   0% 7.61M/4.00G [00:09<1:18:14, 849kB/s]
#
#
#
#
# model-00004-of-00037.safetensors:   8% 300M/4.00G [00:09<01:35, 38.9MB/s]
#
#
#
# model-00006-of-00037.safetensors:   1% 42.1M/4.00G [00:13<20:55, 3.15MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:   2% 74.7M/4.00G [00:16<12:12, 5.35MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  17% 671M/4.00G [00:17<01:17, 43.1MB/s]
#
#
# model-00003-of-00037.safetensors:   2% 67.1M/3.81G [00:17<16:39, 3.75MB/s]
# model-00001-of-00037.safetensors:   2% 67.5M/3.76G [00:18<15:22, 4.00MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:   0% 35.5k/4.00G [00:18<182:34:22, 6.08kB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:   0% 8.32M/3.81G [00:18<52:02, 1.22MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:   6% 239M/4.00G [00:19<03:33, 17.6MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  18% 738M/4.00G [00:19<01:17, 41.8MB/s]
# model-00001-of-00037.safetensors:   4% 135M/3.76G [00:20<07:02, 8.58MB/s]
#
# model-00002-of-00037.safetensors:   2% 67.1M/4.00G [00:20<20:21, 3.21MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  13% 507M/4.00G [00:21<01:27, 39.9MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:   2% 60.7M/4.00G [00:21<21:11, 3.09MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  20% 805M/4.00G [00:23<01:35, 33.3MB/s]
# model-00001-of-00037.safetensors:  12% 470M/3.76G [00:23<01:43, 31.9MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:   2% 75.4M/3.81G [00:24<18:59, 3.28MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  14% 574M/4.00G [00:25<01:49, 31.4MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  25% 1.01G/4.00G [00:25<01:02, 47.5MB/s]
# model-00001-of-00037.safetensors:  14% 537M/3.76G [00:27<01:55, 27.9MB/s]
#
#
#
# model-00006-of-00037.safetensors:   3% 109M/4.00G [00:27<15:56, 4.06MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:   4% 142M/3.81G [00:28<10:01, 6.10MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  19% 775M/4.00G [00:28<01:21, 39.4MB/s]
#
#
# model-00003-of-00037.safetensors:   2% 67.1M/3.81G [00:28<16:39, 3.75MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  29% 1.14G/4.00G [00:28<01:05, 43.7MB/s]
# model-00001-of-00037.safetensors:  20% 738M/3.76G [00:29<01:12, 41.9MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:   3% 128M/4.00G [00:31<13:45, 4.69MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  21% 842M/4.00G [00:31<01:29, 35.1MB/s]
#
#
# model-00003-of-00037.safetensors:   4% 134M/3.81G [00:32<14:24, 4.26MB/s]
# model-00001-of-00037.safetensors:  25% 940M/3.76G [00:32<00:56, 49.8MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:   3% 135M/4.00G [00:35<16:12, 3.97MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  23% 918M/4.00G [00:35<01:45, 29.1MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  31% 1.22G/4.00G [00:36<01:42, 27.2MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:   4% 142M/3.81G [00:38<10:01, 6.10MB/s]
#
#
#
# model-00006-of-00037.safetensors:   3% 109M/4.00G [00:38<15:56, 4.06MB/s]
#
# model-00002-of-00037.safetensors:   2% 67.1M/4.00G [00:38<20:21, 3.21MB/s]
#
#
# model-00003-of-00037.safetensors:   6% 247M/3.81G [00:39<08:09, 7.28MB/s]
# model-00001-of-00037.safetensors:  30% 1.14G/3.76G [00:39<01:09, 37.9MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:   5% 210M/3.81G [00:40<10:17, 5.83MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:   7% 269M/4.00G [00:46<08:04, 7.70MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  31% 1.22G/4.00G [00:48<01:42, 27.2MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  23% 918M/4.00G [00:48<01:45, 29.1MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  32% 1.29G/4.00G [00:50<03:05, 14.6MB/s]
#
#
#
# model-00006-of-00037.safetensors:   4% 176M/4.00G [00:50<18:38, 3.42MB/s]
# model-00001-of-00037.safetensors:  36% 1.34G/3.76G [00:50<01:26, 28.0MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:   7% 277M/3.81G [00:51<09:57, 5.92MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:   8% 336M/4.00G [00:52<07:08, 8.54MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  24% 948M/4.00G [00:56<05:22, 9.46MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  34% 1.36G/4.00G [00:56<03:13, 13.6MB/s]
#
#
# model-00003-of-00037.safetensors:   8% 314M/3.81G [00:56<10:16, 5.67MB/s]
#
#
#
# model-00006-of-00037.safetensors:   6% 243M/4.00G [00:57<13:17, 4.70MB/s]
#
# model-00002-of-00037.safetensors:   3% 134M/4.00G [00:58<29:41, 2.17MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:  10% 403M/4.00G [01:04<08:17, 7.22MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  25% 1.02G/4.00G [01:04<05:28, 9.07MB/s]
#
#
#
# model-00006-of-00037.safetensors:   7% 290M/4.00G [01:05<12:27, 4.96MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:   8% 294M/3.81G [01:05<14:55, 3.93MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  36% 1.42G/4.00G [01:08<03:08, 13.6MB/s]
#
# model-00002-of-00037.safetensors:   5% 201M/4.00G [01:08<29:10, 2.17MB/s]
#
#
# model-00003-of-00037.safetensors:   8% 314M/3.81G [01:08<10:16, 5.67MB/s]
# model-00001-of-00037.safetensors:  37% 1.41G/3.76G [01:08<01:23, 28.0MB/s]
#
# model-00002-of-00037.safetensors:   7% 268M/4.00G [01:09<13:45, 4.51MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  27% 1.08G/4.00G [01:10<05:06, 9.51MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  37% 1.49G/4.00G [01:10<03:37, 11.5MB/s]
#
# model-00002-of-00037.safetensors:  10% 381M/4.00G [01:14<08:49, 6.82MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  29% 1.16G/4.00G [01:14<04:09, 11.3MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:  13% 537M/4.00G [01:15<06:21, 9.06MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  40% 1.59G/4.00G [01:15<03:01, 13.3MB/s]
#
#
# model-00003-of-00037.safetensors:  10% 381M/3.81G [01:15<12:03, 4.74MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:   8% 294M/3.81G [01:18<14:55, 3.93MB/s]
#
#
#
# model-00006-of-00037.safetensors:   7% 290M/4.00G [01:18<12:27, 4.96MB/s]
#
#
#
# model-00006-of-00037.safetensors:   9% 357M/4.00G [01:20<12:50, 4.72MB/s]
# model-00001-of-00037.safetensors:  39% 1.48G/3.76G [01:20<03:06, 12.3MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:   9% 361M/3.81G [01:21<13:57, 4.12MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  31% 1.23G/4.00G [01:21<04:13, 10.9MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:  15% 604M/4.00G [01:21<06:04, 9.30MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:
B/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  36% 1.37G/3.81G [03:28<06:20, 6.41MB/s]
#
#
#
# model-00006-of-00037.safetensors:  37% 1.48G/4.00G [03:28<05:56, 7.07MB/s]
#
# model-00002-of-00037.safetensors:  34% 1.36G/4.00G [03:28<06:12, 7.07MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  50% 1.98G/4.00G [03:28<04:59, 6.73MB/s]
#
# model-00002-of-00037.safetensors:  35% 1.39G/4.00G [03:29<06:53, 6.29MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  51% 2.05G/4.00G [03:29<05:57, 5.45MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:  38% 1.50G/4.00G [03:30<05:43, 7.27MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  66% 2.66G/4.00G [03:30<02:23, 9.35MB/s]
#
#
# model-00003-of-00037.safetensors:  38% 1.46G/3.81G [03:30<06:45, 5.79MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  38% 1.44G/3.81G [03:31<05:33, 7.13MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  55% 2.18G/4.00G [03:31<03:28, 8.69MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:  39% 1.56G/4.00G [03:31<04:39, 8.70MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  68% 2.71G/4.00G [03:32<02:01, 10.5MB/s]
#
#
# model-00003-of-00037.safetensors:  40% 1.53G/3.81G [03:32<04:58, 7.65MB/s]
# model-00001-of-00037.safetensors:  67% 2.51G/3.76G [03:38<02:34, 8.12MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:  41% 1.63G/4.00G [03:48<04:32, 8.70MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  38% 1.44G/3.81G [03:48<05:33, 7.13MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  68% 2.71G/4.00G [03:48<02:01, 10.5MB/s]
#
# model-00002-of-00037.safetensors:  37% 1.46G/4.00G [03:48<06:43, 6.29MB/s]
#
#
# model-00003-of-00037.safetensors:  41% 1.55G/3.81G [03:48<04:55, 7.65MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  55% 2.18G/4.00G [03:48<03:28, 8.69MB/s]
#
#
#
# model-00006-of-00037.safetensors:  37% 1.48G/4.00G [04:02<17:53, 2.35MB/s]
#
#
# model-00003-of-00037.safetensors:  42% 1.59G/3.81G [04:05<08:52, 4.17MB/s]
# model-00001-of-00037.safetensors:  68% 2.58G/3.76G [04:05<04:29, 4.40MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  39% 1.51G/3.81G [04:05<08:53, 4.32MB/s]
#
#
#
# model-00006-of-00037.safetensors:  41% 1.62G/4.00G [04:06<08:30, 4.65MB/s]
#
# model-00002-of-00037.safetensors:  38% 1.53G/4.00G [04:06<08:24, 4.89MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  56% 2.25G/4.00G [04:06<05:58, 4.87MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:  42% 1.69G/4.00G [04:06<06:37, 5.79MB/s]
# model-00001-of-00037.safetensors:  70% 2.63G/3.76G [04:08<03:31, 5.34MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  43% 1.64G/3.81G [04:08<05:16, 6.86MB/s]
#
#
#
# model-00006-of-00037.safetensors:  42% 1.69G/4.00G [04:08<06:31, 5.90MB/s]
#
# model-00002-of-00037.safetensors:  40% 1.59G/4.00G [04:09<06:47, 5.90MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  70% 2.78G/4.00G [04:09<03:54, 5.18MB/s]
#
#
# model-00003-of-00037.safetensors:  46% 1.75G/3.81G [04:10<04:39, 7.38MB/s]
# model-00001-of-00037.safetensors:  72% 2.70G/3.76G [04:10<02:33, 6.92MB/s]
#
#
#
# model-00006-of-00037.safetensors:  44% 1.75G/4.00G [04:10<04:53, 7.63MB/s]
#
# model-00002-of-00037.safetensors:  42% 1.66G/4.00G [04:12<05:33, 6.99MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  60% 2.42G/4.00G [04:12<03:29, 7.55MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:  44% 1.76G/4.00G [04:13<05:51, 6.36MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  70% 2.79G/4.00G [04:13<04:08, 4.85MB/s]
# model-00001-of-00037.safetensors:  72% 2.71G/3.76G [04:14<02:52, 6.11MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  46% 1.77G/3.81G [04:17<03:59, 8.53MB/s]
#
#
#
# model-00006-of-00037.safetensors:  46% 1.82G/4.00G [04:19<04:42, 7.70MB/s]
#
# model-00002-of-00037.safetensors:  45% 1.79G/4.00G [04:19<03:48, 9.62MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  62% 2.48G/4.00G [04:19<03:11, 7.91MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  71% 2.85G/4.00G [04:20<03:25, 5.60MB/s]
#
#
# model-00003-of-00037.safetensors:  49% 1.88G/3.81G [04:20<03:38, 8.83MB/s]
# model-00001-of-00037.safetensors:  73% 2.76G/3.76G [04:20<02:25, 6.87MB/s]
#
# model-00002-of-00037.safetensors:  47% 1.86G/4.00G [04:23<03:21, 10.6MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:  46% 1.83G/4.00G [04:23<05:36, 6.44MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  64% 2.55G/4.00G [04:23<02:40, 8.98MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  48% 1.83G/3.81G [04:28<03:51, 8.53MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  75% 2.98G/4.00G [04:29<02:08, 7.87MB/s]
# model-00001-of-00037.safetensors:  75% 2.83G/3.76G [04:29<02:12, 7.00MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  48% 1.85G/3.81G [04:30<04:13, 7.77MB/s]
#
# model-00002-of-00037.safetensors:  48% 1.93G/4.00G [04:30<03:20, 10.3MB/s]
#
#
#
# model-00006-of-00037.safetensors:  48% 1.91G/4.00G [04:33<04:52, 7.12MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  66% 2.62G/4.00G [04:33<02:45, 8.30MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  75% 2.99G/4.00G [04:34<02:26, 6.89MB/s]
#
#
# model-00003-of-00037.safetensors:  51% 1.95G/3.81G [04:34<04:07, 7.52MB/s]
#
# model-00002-of-00037.safetensors:  50% 2.01G/4.00G [04:35<02:52, 11.5MB/s]
#
#
#
# model-00006-of-00037.safetensors:  51% 2.05G/4.00G [04:35<02:52, 11.3MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:  47% 1.90G/4.00G [04:35<05:41, 6.15MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  77% 3.06G/4.00G [04:36<01:43, 9.03MB/s]
# model-00001-of-00037.safetensors:  76% 2.84G/3.76G [04:36<02:47, 5.49MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  50% 1.91G/3.81G [04:37<03:54, 8.10MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  66% 2.63G/4.00G [04:38<03:03, 7.42MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  77% 3.07G/4.00G [04:39<01:48, 8.52MB/s]
# model-00001-of-00037.safetensors:  78% 2.92G/3.76G [04:40<01:42, 8.22MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  52% 1.98G/3.81G [04:40<03:12, 9.53MB/s]
#
#
#
# model-00006-of-00037.safetensors:  52% 2.09G/4.00G [04:43<03:11, 9.94MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:  51% 2.03G/4.00G [04:43<03:51, 8.49MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  68% 2.70G/4.00G [04:43<02:30, 8.60MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  79% 3.14G/4.00G [04:44<01:26, 9.93MB/s]
#
#
# model-00003-of-00037.safetensors:  54% 2.06G/3.81G [04:44<03:28, 8.39MB/s]
# model-00001-of-00037.safetensors:  79% 2.99G/3.76G [04:45<01:21, 9.49MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  54% 2.05G/3.81G [04:45<02:51, 10.3MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:  54% 2.16G/4.00G [04:47<02:35, 11.8MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  69% 2.77G/4.00G [04:47<02:01, 10.1MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  80% 3.21G/4.00G [04:48<01:08, 11.6MB/s]
#
#
# model-00003-of-00037.safetensors:  56% 2.13G/3.81G [04:48<02:55, 9.57MB/s]
# model-00001-of-00037.safetensors:  85% 3.19G/3.76G [04:48<00:29, 19.2MB/s]
#
# model-00002-of-00037.safetensors:  50% 2.01G/4.00G [04:48<02:52, 11.5MB/s]
#
# model-00002-of-00037.safetensors:  51% 2.02G/4.00G [04:51<05:22, 6.11MB/s]
#
#
#
# model-00006-of-00037.safetensors:  55% 2.21G/4.00G [04:53<02:52, 10.3MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  71% 2.84G/4.00G [04:54<01:52, 10.3MB/s]
# model-00001-of-00037.safetensors:  86% 3.25G/3.76G [04:54<00:31, 16.3MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  56% 2.13G/3.81G [04:54<02:56, 9.58MB/s]
#
# model-00002-of-00037.safetensors:  52% 2.09G/4.00G [04:55<04:01, 7.89MB/s]
#
#
#
# model-00006-of-00037.safetensors:  60% 2.38G/4.00G [04:55<01:32, 17.4MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:  56% 2.23G/4.00G [04:58<02:30, 11.8MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  80% 3.21G/4.00G [04:58<01:08, 11.6MB/s]
#
#
# model-00003-of-00037.safetensors:  56% 2.13G/3.81G [04:58<02:55, 9.57MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:  58% 2.30G/4.00G [04:59<02:28, 11.5MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  73% 2.90G/4.00G [04:59<01:42, 10.6MB/s]
#
#
# model-00003-of-00037.safetensors:  57% 2.16G/3.81G [05:00<03:59, 6.90MB/s]
# model-00001-of-00037.safetensors:  89% 3.36G/3.76G [05:01<00:24, 16.3MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  58% 2.19G/3.81G [05:06<03:16, 8.26MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  74% 2.94G/4.00G [05:07<01:59, 8.85MB/s]
#
#
# model-00003-of-00037.safetensors:  60% 2.29G/3.81G [05:07<02:38, 9.61MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  59% 2.26G/3.81G [05:08<02:31, 10.3MB/s]
# model-00001-of-00037.safetensors:  91% 3.43G/3.76G [05:08<00:23, 13.9MB/s]
#
# model-00002-of-00037.safetensors:  54% 2.16G/4.00G [05:08<04:35, 6.67MB/s]
#
#
#
# model-00006-of-00037.safetensors:  61% 2.45G/4.00G [05:08<02:13, 11.6MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  75% 3.01G/4.00G [05:09<01:25, 11.5MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:  61% 2.43G/4.00G [05:10<02:11, 11.9MB/s]
#
#
# model-00003-of-00037.safetensors:  64% 2.43G/3.81G [05:10<01:39, 13.9MB/s]
#
# model-00002-of-00037.safetensors:  56% 2.22G/4.00G [05:11<03:26, 8.60MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  77% 3.08G/4.00G [05:12<01:06, 13.9MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  82% 3.27G/4.00G [05:13<02:10, 5.51MB/s]
#
# model-00002-of-00037.safetensors:  57% 2.29G/4.00G [05:16<02:56, 9.64MB/s]
#
#
#
# model-00006-of-00037.safetensors:  63% 2.52G/4.00G [05:16<02:17, 10.7MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  64% 2.43G/3.81G [05:18<02:14, 10.3MB/s]
# model-00001-of-00037.safetensors:  91% 3.43G/3.76G [05:18<00:23, 13.9MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:  64% 2.55G/4.00G [05:20<02:01, 11.8MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  84% 3.37G/4.00G [05:20<01:25, 7.29MB/s]
# model-00001-of-00037.safetensors:  93% 3.50G/3.76G [05:20<00:26, 10.0MB/s]
#
#
# model-00003-of-00037.safetensors:  65% 2.48G/3.81G [05:20<02:02, 10.9MB/s]
#
#
#
# model-00006-of-00037.safetensors:  64% 2.57G/4.00G [05:21<02:08, 11.1MB/s]
# model-00001-of-00037.safetensors:  95% 3.56G/3.76G [05:21<00:15, 13.0MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  78% 3.10G/4.00G [05:21<01:42, 8.68MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  86% 3.44G/4.00G [05:23<01:00, 9.16MB/s]
#
# model-00002-of-00037.safetensors:  59% 2.36G/4.00G [05:26<03:13, 8.45MB/s]
#
#
#
# model-00006-of-00037.safetensors:  67% 2.68G/4.00G [05:26<01:37, 13.4MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  79% 3.17G/4.00G [05:27<01:25, 9.62MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  87% 3.47G/4.00G [05:30<01:08, 7.60MB/s]
#
# model-00002-of-00037.safetensors:  60% 2.42G/4.00G [05:30<02:46, 9.48MB/s]
#
#
#
# model-00006-of-00037.safetensors:  69% 2.75G/4.00G [05:31<01:31, 13.6MB/s]
#
#
# model-00003-of-00037.safetensors:  67% 2.55G/3.81G [05:31<02:17, 9.19MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  80% 3.20G/4.00G [05:31<01:29, 8.93MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  89% 3.55G/4.00G [05:32<00:40, 11.1MB/s]
# model-00001-of-00037.safetensors:  96% 3.63G/3.76G [05:32<00:13, 9.96MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  66% 2.50G/3.81G [05:32<02:10, 10.0MB/s]
#
#
# model-00003-of-00037.safetensors:  69% 2.62G/3.81G [05:36<01:59, 9.98MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:  69% 2.75G/4.00G [05:37<01:45, 11.8MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  91% 3.62G/4.00G [05:37<00:33, 11.5MB/s]
# model-00001-of-00037.safetensors:  98% 3.70G/3.76G [05:37<00:06, 10.7MB/s]
#
# model-00002-of-00037.safetensors:  62% 2.48G/4.00G [05:37<02:38, 9.55MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  67% 2.57G/3.81G [05:38<01:59, 10.4MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  85% 3.40G/4.00G [05:40<00:41, 14.4MB/s]
# model-00001-of-00037.safetensors: 100% 3.76G/3.76G [05:41<00:00, 11.0MB/s]
# Fetching 37 files:   3% 1/37 [05:41<3:24:47, 341.32s/it]
# model-00009-of-00037.safetensors:   0% 0.00/4.00G [00:00<?, ?B/s]
#
# model-00002-of-00037.safetensors:  64% 2.55G/4.00G [05:41<02:11, 11.0MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  69% 2.63G/3.81G [05:42<01:43, 11.4MB/s]
#
#
#
# model-00006-of-00037.safetensors:  69% 2.77G/4.00G [05:42<02:25, 8.42MB/s]
#
#
# model-00003-of-00037.safetensors:  70% 2.69G/3.81G [05:42<01:47, 10.5MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  87% 3.47G/4.00G [05:42<00:31, 16.8MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:  72% 2.89G/4.00G [05:42<01:19, 14.0MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  92% 3.68G/4.00G [05:43<00:26, 11.7MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  69% 2.64G/3.81G [05:47<02:03, 9.42MB/s]
#
# model-00002-of-00037.safetensors:  66% 2.62G/4.00G [05:47<02:03, 11.2MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:  74% 2.96G/4.00G [05:47<01:13, 14.0MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  94% 3.77G/4.00G [05:51<00:20, 11.2MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  71% 2.72G/3.81G [05:51<01:39, 11.1MB/s]
#
#
# model-00003-of-00037.safetensors:  72% 2.75G/3.81G [05:51<01:53, 9.33MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:  77% 3.07G/4.00G [05:51<00:56, 16.4MB/s]
#
#
#
# model-00006-of-00037.safetensors:  71% 2.84G/4.00G [05:53<02:33, 7.53MB/s]
#
#
# model-00003-of-00037.safetensors:  73% 2.77G/3.81G [05:53<01:51, 9.35MB/s]
#
# model-00002-of-00037.safetensors:  67% 2.68G/4.00G [05:53<01:56, 11.2MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  87% 3.48G/4.00G [05:57<01:04, 7.97MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:  79% 3.16G/4.00G [05:57<00:51, 16.4MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  95% 3.79G/4.00G [05:58<00:22, 8.90MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  77% 2.93G/3.81G [05:58<00:50, 17.3MB/s]
#
#
#
# model-00006-of-00037.safetensors:  71% 2.84G/4.00G [05:58<03:14, 5.97MB/s]
#
#
# model-00003-of-00037.safetensors:  74% 2.84G/3.81G [05:58<01:36, 10.1MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  89% 3.55G/4.00G [05:59<00:42, 10.5MB/s]
# model-00009-of-00037.safetensors:   0% 5.63M/4.00G [00:20<3:58:09, 279kB/s]
#
# model-00002-of-00037.safetensors:  71% 2.82G/4.00G [06:01<01:28, 13.3MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  79% 3.00G/3.81G [06:01<00:46, 17.4MB/s]
#
#
#
# model-00006-of-00037.safetensors:  73% 2.90G/4.00G [06:01<02:13, 8.19MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  97% 3.86G/4.00G [06:02<00:12, 10.4MB/s]
#
#
# model-00003-of-00037.safetensors:  76% 2.89G/3.81G [06:02<01:23, 11.1MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:  81% 3.23G/4.00G [06:02<00:49, 15.6MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  80% 3.05G/3.81G [06:03<00:39, 19.2MB/s]
#
#
#
# model-00006-of-00037.safetensors:  74% 2.97G/4.00G [06:03<01:29, 11.4MB/s]
#
#
# model-00003-of-00037.safetensors:  77% 2.95G/3.81G [06:04<01:01, 13.9MB/s]
#
#
#
#
# model-00004-of-00037.safetensors:  98% 3.93G/4.00G [06:05<00:05, 12.7MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:  82% 3.29G/4.00G [06:05<00:41, 17.0MB/s]
# model-00009-of-00037.safetensors:   0% 13.0M/4.00G [00:24<1:45:08, 631kB/s]
#
# model-00002-of-00037.safetensors:  74% 2.95G/4.00G [06:05<00:59, 17.6MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  82% 3.11G/3.81G [06:05<00:34, 20.4MB/s]
#
#
#
# model-00006-of-00037.safetensors:  75% 2.99G/4.00G [06:05<01:34, 10.7MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:  84% 3.35G/4.00G [06:06<00:33, 19.5MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  90% 3.60G/4.00G [06:06<00:40, 9.58MB/s]
#
# model-00002-of-00037.safetensors:  77% 3.09G/4.00G [06:06<00:36, 25.0MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  83% 3.18G/3.81G [06:06<00:25, 24.7MB/s]
#
#
# model-00003-of-00037.safetensors:  78% 2.99G/3.81G [06:07<01:00, 13.7MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:  86% 3.46G/4.00G [06:07<00:20, 26.6MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  92% 3.67G/4.00G [06:07<00:25, 12.9MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  85% 3.25G/3.81G [06:11<00:27, 20.6MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  94% 3.74G/4.00G [06:11<00:18, 14.2MB/s]
#
#
#
# model-00006-of-00037.safetensors:  76% 3.05G/4.00G [06:11<01:25, 11.0MB/s]
#
#
# model-00003-of-00037.safetensors:  80% 3.04G/3.81G [06:11<01:00, 12.8MB/s]
#
# model-00002-of-00037.safetensors:  79% 3.17G/4.00G [06:11<00:38, 21.7MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  86% 3.26G/3.81G [06:12<00:25, 21.2MB/s]
#
#
#
# model-00006-of-00037.safetensors:  77% 3.09G/4.00G [06:12<01:08, 13.3MB/s]
#
#
# model-00003-of-00037.safetensors:  80% 3.05G/3.81G [06:12<00:57, 13.2MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:  87% 3.47G/4.00G [06:12<00:30, 17.1MB/s]
#
# model-00002-of-00037.safetensors:  80% 3.19G/4.00G [06:12<00:35, 22.5MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  95% 3.81G/4.00G [06:13<00:10, 18.0MB/s]
# model-00009-of-00037.safetensors:   2% 72.6M/4.00G [00:31<19:45, 3.31MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  86% 3.27G/3.81G [06:13<00:27, 19.6MB/s]
#
#
#
#
# model-00004-of-00037.safetensors: 100% 4.00G/4.00G [06:13<00:00, 10.7MB/s]
#
#
#
#
#
# model-00010-of-00037.safetensors:   0% 0.00/4.00G [00:00<?, ?B/s]
#
# model-00002-of-00037.safetensors:  80% 3.21G/4.00G [06:15<00:43, 18.1MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  88% 3.35G/3.81G [06:16<00:21, 21.7MB/s]
#
#
#
# model-00006-of-00037.safetensors:  79% 3.16G/4.00G [06:16<00:58, 14.4MB/s]
#
#
# model-00003-of-00037.safetensors:  82% 3.12G/3.81G [06:16<00:47, 14.5MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:  87% 3.49G/4.00G [06:16<00:38, 13.3MB/s]
#
# model-00002-of-00037.safetensors:  82% 3.28G/4.00G [06:16<00:30, 23.2MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  97% 3.87G/4.00G [06:17<00:07, 17.5MB/s]
# model-00009-of-00037.safetensors:   3% 140M/4.00G [00:35<10:19, 6.22MB/s]
#
#
#
# model-00006-of-00037.safetensors:  81% 3.22G/4.00G [06:17<00:39, 19.6MB/s]
# model-00009-of-00037.safetensors:   5% 207M/4.00G [00:38<06:50, 9.24MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  90% 3.42G/3.81G [06:20<00:20, 19.6MB/s]
#
#
#
# model-00006-of-00037.safetensors:  84% 3.36G/4.00G [06:20<00:23, 27.0MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:  89% 3.56G/4.00G [06:20<00:30, 14.3MB/s]
#
#
# model-00003-of-00037.safetensors:  84% 3.19G/3.81G [06:21<00:43, 14.3MB/s]
#
# model-00002-of-00037.safetensors:  83% 3.33G/4.00G [06:21<00:36, 18.1MB/s]
# model-00009-of-00037.safetensors:   9% 341M/4.00G [00:44<04:19, 14.1MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors:  99% 3.94G/4.00G [06:26<00:04, 12.3MB/s]
#
#
#
# model-00006-of-00037.safetensors:  86% 3.42G/4.00G [06:26<00:29, 19.4MB/s]
#
#
#
#
#
#
#
# model-00005-of-00037.safetensors: 100% 4.00G/4.00G [06:27<00:00, 10.3MB/s]
#
#
# model-00002-of-00037.safetensors:  85% 3.40G/4.00G [06:27<00:38, 15.5MB/s]
#
#
#
#
#
#
#
# model-00011-of-00037.safetensors:   0% 0.00/3.81G [00:00<?, ?B/s]
# model-00009-of-00037.safetensors:  11% 425M/4.00G [00:49<03:58, 15.0MB/s]
#
#
#
# model-00006-of-00037.safetensors:  87% 3.49G/4.00G [06:32<00:29, 16.9MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:  90% 3.58G/4.00G [06:32<00:57, 7.27MB/s]
#
#
# model-00003-of-00037.safetensors:  87% 3.30G/3.81G [06:33<00:42, 11.9MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:  92% 3.66G/4.00G [06:33<00:27, 12.1MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  91% 3.48G/3.81G [06:34<00:36, 9.17MB/s]
#
#
#
# model-00006-of-00037.safetensors:  88% 3.51G/4.00G [06:34<00:32, 14.8MB/s]
#
#
# model-00003-of-00037.safetensors:  87% 3.32G/3.81G [06:35<00:42, 11.4MB/s]
#
#
# model-00003-of-00037.safetensors:  92% 3.49G/3.81G [06:35<00:12, 25.3MB/s]
#
# model-00002-of-00037.safetensors:  87% 3.50G/4.00G [06:35<00:37, 13.5MB/s]
#
#
# model-00003-of-00037.safetensors:  92% 3.53G/3.81G [06:35<00:09, 28.7MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  91% 3.48G/3.81G [06:36<00:40, 8.26MB/s]
# model-00009-of-00037.safetensors:  13% 537M/4.00G [00:54<03:24, 17.0MB/s]
#
#
#
# model-00006-of-00037.safetensors:  88% 3.52G/4.00G [06:36<00:32, 14.5MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:  92% 3.69G/4.00G [06:36<00:26, 11.7MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  92% 3.50G/3.81G [06:36<00:31, 9.78MB/s]
#
#
#
# model-00006-of-00037.safetensors:  90% 3.59G/4.00G [06:37<00:18, 21.3MB/s]
#
#
# model-00003-of-00037.safetensors:  94% 3.59G/3.81G [06:37<00:06, 32.2MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:  93% 3.73G/4.00G [06:38<00:20, 13.3MB/s]
#
#
#
# model-00006-of-00037.safetensors:  91% 3.64G/4.00G [06:40<00:19, 18.0MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:  95% 3.79G/4.00G [06:40<00:12, 16.2MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  93% 3.54G/3.81G [06:41<00:26, 9.95MB/s]
#
# model-00002-of-00037.safetensors:  89% 3.56G/4.00G [06:41<00:33, 13.1MB/s]
#
#
# model-00003-of-00037.safetensors:  95% 3.61G/3.81G [06:42<00:10, 18.8MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:  97% 3.86G/4.00G [06:42<00:06, 21.7MB/s]
#
# model-00002-of-00037.safetensors:  91% 3.62G/4.00G [06:42<00:23, 16.1MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  95% 3.61G/3.81G [06:42<00:13, 14.8MB/s]
#
#
# model-00003-of-00037.safetensors:  96% 3.68G/3.81G [06:45<00:06, 19.8MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors:  98% 3.93G/4.00G [06:46<00:03, 19.0MB/s]
#
# model-00002-of-00037.safetensors:  92% 3.69G/4.00G [06:46<00:19, 16.1MB/s]
#
#
#
#
# model-00010-of-00037.safetensors:   2% 67.1M/4.00G [00:32<31:57, 2.05MB/s]
# model-00009-of-00037.safetensors:  13% 538M/4.00G [01:07<03:23, 17.0MB/s]
#
#
#
# model-00006-of-00037.safetensors:  92% 3.69G/4.00G [06:50<00:28, 10.5MB/s]
#
#
#
#
# model-00010-of-00037.safetensors:   2% 83.9M/4.00G [00:36<27:18, 2.39MB/s]
#
# model-00002-of-00037.safetensors:  94% 3.75G/4.00G [06:50<00:14, 16.5MB/s]
#
#
# model-00003-of-00037.safetensors:  98% 3.75G/3.81G [06:51<00:04, 15.7MB/s]
#
# model-00002-of-00037.safetensors:  95% 3.79G/4.00G [06:51<00:10, 18.9MB/s]
# model-00009-of-00037.safetensors:  15% 605M/4.00G [01:10<05:42, 9.89MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  96% 3.68G/3.81G [06:56<00:16, 8.21MB/s]
# model-00009-of-00037.safetensors:  17% 672M/4.00G [01:15<05:16, 10.5MB/s]
#
#
#
# model-00006-of-00037.safetensors:  94% 3.76G/4.00G [06:56<00:22, 10.5MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors:  98% 3.75G/3.81G [06:57<00:05, 12.2MB/s]
#
#
#
# model-00006-of-00037.safetensors:  95% 3.79G/4.00G [06:57<00:16, 12.4MB/s]
#
#
#
#
#
# model-00008-of-00037.safetensors: 100% 4.00G/4.00G [06:57<00:00, 9.56MB/s]
#
#
#
#
# model-00006-of-00037.safetensors:  97% 3.86G/4.00G [06:58<00:07, 18.9MB/s]
#
#
#
#
#
# model-00012-of-00037.safetensors:   0% 0.00/4.00G [00:00<?, ?B/s]
# model-00009-of-00037.safetensors:  19% 741M/4.00G [01:16<04:01, 13.5MB/s]
#
#
#
#
# model-00010-of-00037.safetensors:   5% 218M/4.00G [00:45<09:46, 6.44MB/s]
# model-00009-of-00037.safetensors:  20% 808M/4.00G [01:19<03:25, 15.5MB/s]
#
# model-00002-of-00037.safetensors:  97% 3.86G/4.00G [07:01<00:11, 11.9MB/s]
#
#
#
# model-00006-of-00037.safetensors:  98% 3.93G/4.00G [07:02<00:03, 17.9MB/s]
#
#
#
#
# model-00010-of-00037.safetensors:   7% 285M/4.00G [00:48<07:03, 8.76MB/s]
#
#
#
#
#
#
#
# model-00011-of-00037.safetensors:   2% 67.1M/3.81G [00:34<32:25, 1.92MB/s]
#
#
#
# model-00006-of-00037.safetensors: 100% 4.00G/4.00G [07:04<00:00, 9.42MB/s]
#
#
#
#
#
# model-00010-of-00037.safetensors:   8% 336M/4.00G [00:50<05:41, 10.7MB/s]
#
#
#
# model-00013-of-00037.safetensors:   0% 0.00/4.00G [00:00<?, ?B/s]
#
#
#
#
#
#
#
# model-00011-of-00037.safetensors:   2% 92.4M/3.81G [00:39<24:46, 2.50MB/s]
#
#
#
#
#
#
# model-00007-of-00037.safetensors: 100% 3.81G/3.81G [07:07<00:00, 8.92MB/s]
#
#
#
#
#
#
#
# model-00014-of-00037.safetensors:   0% 0.00/4.00G [00:00<?, ?B/s]
#
#
#
#
# model-00010-of-00037.safetensors:  10% 403M/4.00G [00:53<04:49, 12.4MB/s]
#
#
# model-00003-of-00037.safetensors:  98% 3.75G/3.81G [07:08<00:04, 15.7MB/s]
# model-00009-of-00037.safetensors:  24% 942M/4.00G [01:31<03:53, 13.1MB/s]
#
#
#
#
#
#
#
# model-00011-of-00037.safetensors:   6% 215M/3.81G [00:45<09:08, 6.55MB/s]
#
#
#
#
# model-00010-of-00037.safetensors:  12% 470M/4.00G [00:59<04:45, 12.3MB/s]
#
# model-00002-of-00037.safetensors:  98% 3.93G/4.00G [07:13<00:07, 8.60MB/s]
#
# model-00002-of-00037.safetensors: 100% 4.00G/4.00G [07:14<00:00, 9.19MB/s]
# Fetching 37 files:   5% 2/37 [07:15<1:54:09, 195.70s/it]
# model-00009-of-00037.safetensors:  25% 1.01G/4.00G [01:33<03:12, 15.6MB/s]
#
#
#
#
#
#
#
# model-00011-of-00037.safetensors:   7% 282M/3.81G [00:47<06:22, 9.23MB/s]
#
# model-00015-of-00037.safetensors:   0% 0.00/3.81G [00:00<?, ?B/s]
#
#
#
#
#
# model-00012-of-00037.safetensors:   1% 22.5M/4.00G [00:21<1:03:06, 1.05MB/s]
# model-00009-of-00037.safetensors:  29% 1.14G/4.00G [01:38<02:33, 18.5MB/s]
#
#
#
#
#
#
#
# model-00011-of-00037.safetensors:   9% 349M/3.81G [00:52<05:40, 10.2MB/s]
#
#
#
#
# model-00010-of-00037.safetensors:  16% 636M/4.00G [01:09<03:55, 14.3MB/s]
#
#
# model-00003-of-00037.safetensors: 100% 3.81G/3.81G [07:23<00:00, 8.59MB/s]
#
#
#
#
# Fetching 37 files:   8% 3/37 [07:24<1:02:35, 110.45s/it]9<3:04:13, 361kB/s]
#
#
# model-00016-of-00037.safetensors:   0% 0.00/4.00G [00:00<?, ?B/s]
#
#
#
#
#
#
#
# model-00011-of-00037.safetensors:  11% 433M/3.81G [01:01<05:46, 9.75MB/s]
#
#
#
#
# model-00010-of-00037.safetensors:  18% 738M/4.00G [01:15<03:38, 14.9MB/s]
# model-00009-of-00037.safetensors:  32% 1.28G/4.00G [01:52<03:14, 14.0MB/s]
#
#
#
#
#
#
#
# model-00011-of-00037.safetensors:
B/s]
#
#
#
#
#
#
# model-00014-of-00037.safetensors:   8% 304M/4.00G [01:11<10:33, 5.83MB/s]
#
#
# model-00016-of-00037.safetensors:   3% 101M/4.00G [00:55<34:01, 1.91MB/s]
# model-00009-of-00037.safetensors:  55% 2.18G/4.00G [02:38<02:26, 12.4MB/s]
#
#
#
# model-00013-of-00037.safetensors:  11% 425M/4.00G [01:17<05:32, 10.7MB/s]
#
#
# model-00016-of-00037.safetensors:   4% 141M/4.00G [00:59<21:39, 2.97MB/s]
# model-00009-of-00037.safetensors:  58% 2.33G/4.00G [02:45<01:50, 15.1MB/s]
#
#
#
#
#
#
#
# model-00011-of-00037.safetensors:  37% 1.41G/3.81G [01:59<03:29, 11.5MB/s]
#
# model-00015-of-00037.safetensors:   4% 137M/3.81G [01:13<49:44, 1.23MB/s]
#
#
#
#
# model-00010-of-00037.safetensors:  39% 1.57G/4.00G [02:14<02:53, 14.0MB/s]
#
#
#
#
#
# model-00012-of-00037.safetensors:  13% 537M/4.00G [01:30<04:12, 13.7MB/s]
#
#
#
#
#
#
# model-00014-of-00037.safetensors:   8% 304M/4.00G [01:21<10:33, 5.83MB/s]
#
#
#
# model-00013-of-00037.safetensors:  14% 560M/4.00G [01:26<04:44, 12.1MB/s]
#
#
#
#
#
#
# model-00014-of-00037.safetensors:   9% 372M/4.00G [01:23<10:47, 5.59MB/s]
# model-00009-of-00037.safetensors:  62% 2.46G/4.00G [02:50<01:27, 17.6MB/s]
#
# model-00015-of-00037.safetensors:   5% 204M/3.81G [01:19<18:22, 3.27MB/s]
#
#
#
# model-00013-of-00037.safetensors:  16% 627M/4.00G [01:32<04:40, 12.0MB/s]
#
#
#
#
#
#
# model-00014-of-00037.safetensors:  13% 537M/4.00G [01:28<05:21, 10.7MB/s]
#
#
# model-00016-of-00037.safetensors:   5% 202M/4.00G [01:13<18:06, 3.49MB/s]
# model-00009-of-00037.safetensors:  65% 2.60G/4.00G [02:55<01:10, 19.7MB/s]
#
#
#
#
#
# model-00012-of-00037.safetensors:  15% 604M/4.00G [01:39<07:05, 7.98MB/s]
#
#
#
#
#
#
#
# model-00011-of-00037.safetensors:  41% 1.55G/3.81G [02:11<03:17, 11.5MB/s]
#
#
#
#
# model-00010-of-00037.safetensors:  41% 1.64G/4.00G [02:29<05:13, 7.52MB/s]
#
# model-00015-of-00037.safetensors:   7% 272M/3.81G [01:28<14:27, 4.08MB/s]
#
#
#
#
#
#
# model-00014-of-00037.safetensors:  15% 604M/4.00G [01:35<05:24, 10.5MB/s]
#
#
# model-00016-of-00037.safetensors:   7% 269M/4.00G [01:23<14:12, 4.37MB/s]
# model-00009-of-00037.safetensors:  66% 2.62G/4.00G [03:06<01:50, 12.4MB/s]
#
#
#
#
#
# model-00012-of-00037.safetensors:  18% 738M/4.00G [01:50<05:49, 9.33MB/s]
#
#
#
# model-00013-of-00037.safetensors:  16% 627M/4.00G [01:44<04:40, 12.0MB/s]
#
#
#
#
# model-00010-of-00037.safetensors:  43% 1.70G/4.00G [02:35<04:44, 8.07MB/s]
#
#
#
# model-00013-of-00037.safetensors:  17% 694M/4.00G [01:46<06:28, 8.51MB/s]
#
#
#
#
#
#
# model-00014-of-00037.safetensors:  17% 672M/4.00G [01:44<05:44, 9.65MB/s]
#
#
# ...
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/_snapshot_download.py", line 306, in _inner_hf_hub_download
#     return hf_hub_download(
#            ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py", line 114, in _inner_fn
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 1014, in hf_hub_download
#     return _hf_hub_download_to_cache_dir(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 1175, in _hf_hub_download_to_cache_dir
#     _download_to_tmp_and_move(
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 1727, in _download_to_tmp_and_move
#     xet_get(
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 633, in xet_get
#     download_files(
# RuntimeError: Data processing error: CAS service error : IO Error: No space left on device (os error 28)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/transformers/pipelines/base.py", line 311, in infer_framework_load_model
#     model = model_class.from_pretrained(model, **fp32_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/auto/auto_factory.py", line 604, in from_pretrained
#     return model_class.from_pretrained(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py", line 277, in _wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py", line 4900, in from_pretrained
#     checkpoint_files, sharded_metadata = _get_resolved_checkpoint_files(
#                                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py", line 1200, in _get_resolved_checkpoint_files
#     checkpoint_files, sharded_metadata = get_checkpoint_shard_files(
#                                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/utils/hub.py", line 1084, in get_checkpoint_shard_files
#     cached_filenames = cached_files(
#                        ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/utils/hub.py", line 567, in cached_files
#     raise e
#   File "/usr/local/lib/python3.12/dist-packages/transformers/utils/hub.py", line 494, in cached_files
#     snapshot_download(
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py", line 114, in _inner_fn
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/_snapshot_download.py", line 332, in snapshot_download
#     thread_map(
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/contrib/concurrent.py", line 69, in thread_map
#     return _executor_map(ThreadPoolExecutor, fn, *iterables, **tqdm_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/contrib/concurrent.py", line 51, in _executor_map
#     return list(tqdm_class(ex.map(fn, *iterables, chunksize=chunksize), **kwargs))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 1181, in __iter__
#     for obj in iterable:
#                ^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 619, in result_iterator
#     yield _result_or_cancel(fs.pop())
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 317, in _result_or_cancel
#     return fut.result(timeout)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 456, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/_snapshot_download.py", line 306, in _inner_hf_hub_download
#     return hf_hub_download(
#            ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py", line 114, in _inner_fn
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 1014, in hf_hub_download
#     return _hf_hub_download_to_cache_dir(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 1175, in _hf_hub_download_to_cache_dir
#     _download_to_tmp_and_move(
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 1727, in _download_to_tmp_and_move
#     xet_get(
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 633, in xet_get
#     download_files(
# RuntimeError: Data processing error: CAS service error : IO Error: No space left on device (os error 28)
#
# while loading with TFAutoModelForCausalLM, an error is thrown:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/transformers/pipelines/base.py", line 293, in infer_framework_load_model
#     model = model_class.from_pretrained(model, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/auto/auto_factory.py", line 607, in from_pretrained
#     raise ValueError(
# ValueError: Unrecognized configuration class <class 'transformers.models.qwen2.configuration_qwen2.Qwen2Config'> for this kind of AutoModel: TFAutoModelForCausalLM.
# Model type should be one of BertConfig, CamembertConfig, CTRLConfig, GPT2Config, GPT2Config, GPTJConfig, MistralConfig, OpenAIGPTConfig, OPTConfig, RemBertConfig, RobertaConfig, RobertaPreLayerNormConfig, RoFormerConfig, TransfoXLConfig, XGLMConfig, XLMConfig, XLMRobertaConfig, XLNetConfig.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/transformers/pipelines/base.py", line 311, in infer_framework_load_model
#     model = model_class.from_pretrained(model, **fp32_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/auto/auto_factory.py", line 607, in from_pretrained
#     raise ValueError(
# ValueError: Unrecognized configuration class <class 'transformers.models.qwen2.configuration_qwen2.Qwen2Config'> for this kind of AutoModel: TFAutoModelForCausalLM.
# Model type should be one of BertConfig, CamembertConfig, CTRLConfig, GPT2Config, GPT2Config, GPTJConfig, MistralConfig, OpenAIGPTConfig, OPTConfig, RemBertConfig, RobertaConfig, RobertaPreLayerNormConfig, RoFormerConfig, TransfoXLConfig, XGLMConfig, XLMConfig, XLMRobertaConfig, XLNetConfig.
#
# while loading with Qwen2ForCausalLM, an error is thrown:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/transformers/pipelines/base.py", line 293, in infer_framework_load_model
#     model = model_class.from_pretrained(model, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py", line 277, in _wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py", line 4900, in from_pretrained
#     checkpoint_files, sharded_metadata = _get_resolved_checkpoint_files(
#                                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py", line 1200, in _get_resolved_checkpoint_files
#     checkpoint_files, sharded_metadata = get_checkpoint_shard_files(
#                                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/utils/hub.py", line 1084, in get_checkpoint_shard_files
#     cached_filenames = cached_files(
#                        ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/utils/hub.py", line 567, in cached_files
#     raise e
#   File "/usr/local/lib/python3.12/dist-packages/transformers/utils/hub.py", line 494, in cached_files
#     snapshot_download(
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py", line 114, in _inner_fn
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/_snapshot_download.py", line 332, in snapshot_download
#     thread_map(
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/contrib/concurrent.py", line 69, in thread_map
#     return _executor_map(ThreadPoolExecutor, fn, *iterables, **tqdm_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/contrib/concurrent.py", line 51, in _executor_map
#     return list(tqdm_class(ex.map(fn, *iterables, chunksize=chunksize), **kwargs))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 1181, in __iter__
#     for obj in iterable:
#                ^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 619, in result_iterator
#     yield _result_or_cancel(fs.pop())
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 317, in _result_or_cancel
#     return fut.result(timeout)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 456, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/_snapshot_download.py", line 306, in _inner_hf_hub_download
#     return hf_hub_download(
#            ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py", line 114, in _inner_fn
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 1014, in hf_hub_download
#     return _hf_hub_download_to_cache_dir(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 1175, in _hf_hub_download_to_cache_dir
#     _download_to_tmp_and_move(
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 1727, in _download_to_tmp_and_move
#     xet_get(
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 633, in xet_get
#     download_files(
# RuntimeError: Data processing error: CAS service error : IO Error: No space left on device (os error 28)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/transformers/pipelines/base.py", line 311, in infer_framework_load_model
#     model = model_class.from_pretrained(model, **fp32_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py", line 277, in _wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py", line 4900, in from_pretrained
#     checkpoint_files, sharded_metadata = _get_resolved_checkpoint_files(
#                                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py", line 1200, in _get_resolved_checkpoint_files
#     checkpoint_files, sharded_metadata = get_checkpoint_shard_files(
#                                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/utils/hub.py", line 1084, in get_checkpoint_shard_files
#     cached_filenames = cached_files(
#                        ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/utils/hub.py", line 567, in cached_files
#     raise e
#   File "/usr/local/lib/python3.12/dist-packages/transformers/utils/hub.py", line 494, in cached_files
#     snapshot_download(
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py", line 114, in _inner_fn
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/_snapshot_download.py", line 332, in snapshot_download
#     thread_map(
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/contrib/concurrent.py", line 69, in thread_map
#     return _executor_map(ThreadPoolExecutor, fn, *iterables, **tqdm_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/contrib/concurrent.py", line 51, in _executor_map
#     return list(tqdm_class(ex.map(fn, *iterables, chunksize=chunksize), **kwargs))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 1181, in __iter__
#     for obj in iterable:
#                ^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 619, in result_iterator
#     yield _result_or_cancel(fs.pop())
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 317, in _result_or_cancel
#     return fut.result(timeout)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 456, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/_snapshot_download.py", line 306, in _inner_hf_hub_download
#     return hf_hub_download(
#            ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py", line 114, in _inner_fn
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 1014, in hf_hub_download
#     return _hf_hub_download_to_cache_dir(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 1175, in _hf_hub_download_to_cache_dir
#     _download_to_tmp_and_move(
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 1727, in _download_to_tmp_and_move
#     xet_get(
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 633, in xet_get
#     download_files(
# RuntimeError: Data processing error: CAS service error : IO Error: No space left on device (os error 28)
